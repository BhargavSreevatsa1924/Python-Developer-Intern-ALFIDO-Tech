# %% [markdown]
# Program for doing basic mathematic opeations

# %%
a = 2
b = 3
# a = int(input("enter the nunber a"))
# b = int(input("enter the nunber b"))

Addition = a + b
print("The Addition of the numbers {0} and {1} is {2}".format(a,b,Addition))

Subraction = a - b
print("The Subraction of the numbers {0} and {1} is {2}".format(a,b,Subraction))

Multiplication = a * b
print("The Multiplication of the numbers {0} and {1} is {2}".format(a,b,Multiplication))

Division = a / b
print("The Division of the numbers {0} and {1} is {2}".format(a,b,Division))
# Out:
# The Addition of the numbers 2 and 3 is 5
# The Subraction of the numbers 2 and 3 is -1
# The Multiplication of the numbers 2 and 3 is 6
# The Division of the numbers 2 and 3 is 0.6666666666666666
