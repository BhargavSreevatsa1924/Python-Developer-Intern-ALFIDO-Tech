# %% [markdown]
# Program to convert given temperaature into Celsius, Kelvin and Fahrenheit

# %%
# Temperature conversion 
def celsius_to_fahrenheit():
    c = float(input("enter the value in celsius: "))
    f = (c * 9/5) + 32
    print("the temperature in fahreheit is: {0} degree F".format(f))


def fahrenheit_to_celsius():
    f = float(input("Enter the value in Fahrenheit: "))
    c = (f - 32) * 5/9
    print("The Temperature in Celsius is: {0} degree C".format(c))


def celsius_to_kelvin():
      c = float(input("enter the value in celsius: "))
      k = c + 273.15
      print("The Temperature in Kelvin is: {0} K".format(k))


def kelvin_to_celsius():
    k= float(input("enter the value in Kelvin: "))
    c = k - 273.15
    print("The Temperature in Celsius is: {0} degree C".format(c))



def fahrenheit_to_kelvin():
    f = float(input("Enter the value in Fahrenheit: "))
    k = ((f -32) /1.8) + 273.15
    print("The Temperature in Kelvin is: {0} K".format(k))


def kelvin_to_fahrenheit():
    k = float(input("Enter the value in Kelvin: "))
    f = ((k - 273.15) *1.8) + 32
    print("the temperature in fahreheit is: {0} degree F".format(f))



#print("c to k is:",celsius_to_kelvin(c))
#print("c to f is:",celsius_to_fahrenheit(c))
# print("f to k is:", fahrenheit_to_kelvin(c))

celsius_to_fahrenheit() # input is 0

fahrenheit_to_celsius() # input is 32 

kelvin_to_celsius() # input is 0

celsius_to_kelvin() # input is 273.15

fahrenheit_to_kelvin() # input is 32

kelvin_to_celsius() # input is 273.15
